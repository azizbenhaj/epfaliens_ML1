# %%
import os
import numpy as np
import pandas as pd

DATA_FOLDER = "data/dataset_to_release/x_train.csv"
# Load x_train data
x_train = pd.read_csv(DATA_FOLDER)

# %%
df = pd.DataFrame
array = np.array(x_train.columns)
array.reshape(-1)
all_columns = pd.Series(array)

selected_columns = pd.Series( ["_RFHLTH","_HCVU651","_RFHYPE5","_RFCHOL","_LTASTH1","_ASTHMS1","_AGEG5YR",
                                       "_CHLDCNT","_EDUCAG","_INCOMG","_SMOKER3","FTJUDA1_","_TOTINDA","_LMTWRK1",
                                       "_RFSEAT2","_FLSHOT6","_AIDTST3","_CHOLCHK","_MICHD","_DRDXAR1","_RACEG21",
                                       "_RACEGR3","_RACE_G1","_AGEG5YR","_BMI5","_RFBMI5","_RFSMOK3",
                                       "_DRNKWEK","_RFDRHV5","FRUTDA1_","VEGEDA1_","_FRUTSUM","_VEGESUM","_TOTINDA",
                                       "MAXVO2_","FC60_","ACTIN11_","ACTIN21_","PAFREQ1_","PAFREQ2_","_MINAC11","_MINAC21",
                                       "STRFREQ_","_PAINDX1","_LMTACT1","_LMTWRK1","_LMTSCL1","_FLSHOT6","_PNEUMO2","_AIDTST3"])

# select specific columns
#selected_columns = pd.Series(["_LMTSCL1"])
                        


                           
df = pd.DataFrame()
df["columns"] = all_columns
print(df.shape)

df1 = df[df["columns"].isin (selected_columns)]
df1.index -1
# Out:
# (322, 1)
#             Id  _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE  \
# 0            0      53      11  11162015      11    16   2015      1100
# 1            1      33      12  12152015      12    15   2015      1200
# 2            2      20      10  10202015      10    20   2015      1100
# 3            3      42       6   6182015       6    18   2015      1100
# 4            4      24      11  11062015      11     6   2015      1100
# ...        ...     ...     ...       ...     ...   ...    ...       ...
# 328130  328130      49       7  11232015      11    23   2015      1100
# 328131  328131      51       5   6082015       6     8   2015      1100
# 328132  328132      39      10  10202015      10    20   2015      1100
# 328133  328133      33      12  12302015      12    30   2015      1100
# 328134  328134      32       9   9122015       9    12   2015      1100
#
#              SEQNO        _PSU  ...  _PAREC1  _PASTAE1  _LMTACT1  _LMTWRK1  \
# ...

# %%
print(x_train.iloc(306))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/project1-grading/lib/python3.9/site-packages/pandas/core/generic.py in ?(cls, axis)
#     554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
# --> 556             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 306
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/g4/rzc_8mgd15n5f0l73k0mm3600000gn/T/ipykernel_13156/1861609163.py in ?()
# ----> 1 print(x_train.iloc(306))
#
# ~/anaconda3/envs/project1-grading/lib/python3.9/site-packages/pandas/core/indexing.py in ?(self, axis)
#     664         # we need to return a copy of ourselves
#     665         new_self = type(self)(self.name, self.obj)
#     666
# ...

# %%
selected_columns1 = pd.Series(["_AGEG5YR"])

# %%
print(selected_columns1.index-1)
# Out:
# RangeIndex(start=-1, stop=0, step=1)
